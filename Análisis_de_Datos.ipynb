# %%
import  pandas as pd

# %%
 datos  = pd.read_csv('/content/materias (2).csv')

# %%
datos
# Out:
#     Alumno Curso  Materias Previas  Materias Desaprobadas
# 0      Ana    5A                 2                      1
# 1     Pepe    4B                 1                      4
# 2    Juana    5A                 0                      3
# 3    Lucia    3C                 2                      0
# 4      pao    5B                 0                      2
# 5     Mili    6A                 3                      1
# 6    Kevin    5B                 4                      2
# 7  Luciano    3A                 5                      2
# 8   Selena    6B                 1                      0

# %%
df1 = pd.DataFrame(datos)

# %%
datos.head(1)
# Out:
#   Alumno Curso  Materias Previas  Materias Desaprobadas
# 0    Ana    5A                 2                      1

# %%
datos.tail(1)
# Out:
#    Alumno Curso  Materias Previas  Materias Desaprobadas
# 8  Selena    6B                 1                      0

# %%
previas_filtrado = df1["Materias Previas"]==0

# %%
df1[previas_filtrado]
# Out:
#   Alumno Curso  Materias Previas  Materias Desaprobadas
# 2  Juana    5A                 0                      3
# 4    pao    5B                 0                      2
